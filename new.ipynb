# %%
import requests
import numpy as np
import tensorflow as tf
import pandas as pd

# API endpoint
url = "https://db.ygoprodeck.com/api/v7/cardinfo.php"

# Request parameters
params = {

}

word_list = dict()
subtype_list = dict()
char_list = dict()
card_number_listed = 0

try:
    response = requests.get(url, params=params)
    data = response.json()

    if response.status_code == 200:
        cards = pd.DataFrame(data=data["data"])
        
except requests.exceptions.RequestException as e:
    print("An error occurred:", e)

# %%
cards.head()
# Out:
#          id                           name        type frameType  \
# 0  34541863       "A" Cell Breeding Device  Spell Card     spell
# 1  64163367             "A" Cell Incubator  Spell Card     spell
# 2  91231901  "A" Cell Recombination Device  Spell Card     spell
# 3  73262676         "A" Cell Scatter Burst  Spell Card     spell
# 4  98319530     "Infernoble Arms - Almace"  Spell Card     spell
#
#                                                 desc        race  \
# 0  During each of your Standby Phases, put 1 A-Co...  Continuous
# 1  Each time an A-Counter(s) is removed from play...  Continuous
# 2  Target 1 face-up monster on the field; send 1 ...  Quick-Play
# 3  Select 1 face-up "Alien" monster you control. ...  Quick-Play
# 4  While this card is equipped to a monster: You ...       Equip
#
#       archetype                                          card_sets  \
# 0         Alien  [{'set_name': 'Force of the Breaker', 'set_cod...
# 1         Alien  [{'set_name': 'Gladiator's Assault', 'set_code...
# 2         Alien  [{'set_name': 'Invasion: Vengeance', 'set_code...
# 3         Alien  [{'set_name': 'Strike of Neos', 'set_code': 'S...
# 4  Noble Knight                                                NaN
#
#                                          card_images  \
# 0  [{'id': 34541863, 'image_url': 'https://images...
# 1  [{'id': 64163367, 'image_url': 'https://images...
# 2  [{'id': 91231901, 'image_url': 'https://images...
# 3  [{'id': 73262676, 'image_url': 'https://images...
# 4  [{'id': 98319530, 'image_url': 'https://images...
#
#                                          card_prices  atk  def  level  \
# 0  [{'cardmarket_price': '0.12', 'tcgplayer_price...  NaN  NaN    NaN
# 1  [{'cardmarket_price': '0.23', 'tcgplayer_price...  NaN  NaN    NaN
# 2  [{'cardmarket_price': '0.12', 'tcgplayer_price...  NaN  NaN    NaN
# 3  [{'cardmarket_price': '0.16', 'tcgplayer_price...  NaN  NaN    NaN
# 4  [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
#
#   attribute  scale  linkval linkmarkers banlist_info
# 0       NaN    NaN      NaN         NaN          NaN
# 1       NaN    NaN      NaN         NaN          NaN
# 2       NaN    NaN      NaN         NaN          NaN
# 3       NaN    NaN      NaN         NaN          NaN
# 4       NaN    NaN      NaN         NaN          NaN

# %%
# Show count of each type of card
cards["type"].value_counts()
# Out:
# type
# Effect Monster                     4513
# Spell Card                         2436
# Trap Card                          1849
# Normal Monster                      657
# XYZ Monster                         489
# Fusion Monster                      437
# Tuner Monster                       435
# Synchro Monster                     400
# Link Monster                        380
# Pendulum Effect Monster             254
# Flip Effect Monster                 178
# Skill Card                          124
# Ritual Effect Monster               111
# Token                               107
# Gemini Monster                       45
# Pendulum Normal Monster              41
# Union Effect Monster                 36
# Spirit Monster                       33
# Synchro Tuner Monster                23
# Toon Monster                         17
# Ritual Monster                       15
# Pendulum Effect Fusion Monster       11
# Normal Tuner Monster                 10
# XYZ Pendulum Effect Monster           9
# Pendulum Tuner Effect Monster         8
# Synchro Pendulum Effect Monster       7
# Pendulum Effect Ritual Monster        1
# Pendulum Flip Effect Monster          1
# Name: count, dtype: int64

# %%
# Show NaN values
cards.isnull().sum()
# Out:
# id                  0
# name                0
# type                0
# frameType           0
# desc                0
# race                0
# archetype        5357
# card_sets         496
# card_images         0
# card_prices         0
# atk              4409
# def              4789
# level            4789
# attribute        4409
# scale           12295
# linkval         12247
# linkmarkers     12247
# banlist_info    12339
# dtype: int64

# %%
# Show card prices for first 5 cards
cards["card_prices"].head()
# Out:
# 0    [{'cardmarket_price': '0.12', 'tcgplayer_price...
# 1    [{'cardmarket_price': '0.23', 'tcgplayer_price...
# 2    [{'cardmarket_price': '0.12', 'tcgplayer_price...
# 3    [{'cardmarket_price': '0.16', 'tcgplayer_price...
# 4    [{'cardmarket_price': '0.00', 'tcgplayer_price...
# Name: card_prices, dtype: object

# %%
# Show cards with round brackets in their names
cards[cards["name"].str.contains("\(")]
# Out:
#               id                                       name             type  \
# 1179   300302024  Blaze Accelerator Deployment (Skill Card)       Skill Card
# 1512   300101003           Call of the Haunted (Skill Card)       Skill Card
# 1828   300104004     Cocoon of Ultra Evolution (Skill Card)       Skill Card
# 2000    63436931                      Crimson Dragon (card)  Synchro Monster
# 2220   300302028               Cyberdark Style (Skill Card)       Skill Card
# 2729   300201002                  Destiny Draw (Skill Card)       Skill Card
# 3054   300103005         Double Evolution Pill (Skill Card)       Skill Card
# 5192   300103001           Heavy Metal Raiders (Skill Card)       Skill Card
# 6122   300302033            Land of the Ojamas (Skill Card)       Skill Card
# 7097   300302036              Middle Age Mechs (Skill Card)       Skill Card
# 7113   300201009                Millennium Eye (Skill Card)       Skill Card
# 7115   300201006           Millennium Necklace (Skill Card)       Skill Card
# 7141   300201008                     Mind Scan (Skill Card)       Skill Card
# 8483   300302051                    Power Bond (Skill Card)       Skill Card
# 8945    40551410        Recette de Personnel (Staff Recipe)        Trap Card
# 8946    87778106           Recette de Poisson (Fish Recipe)       Spell Card
# 8947    14166715            Recette de Viande (Meat Recipe)       Spell Card
# 10118  300302053                 Spell of Mask (Skill Card)       Skill Card
# 11960   41773061              Voici la Carte (Today's Menu)       Spell Card
# 12574  300104001                 Zombie Master (Skill Card)       Skill Card
#
#       frameType                                               desc  \
# 1179      skill  Once per turn, you can change the name of 1 "B...
# 1512      skill  [At the start of the Duel, place this card in ...
# 1828      skill  Activate the following Skill(s) during your Ma...
# 2000    synchro  1 Tuner + 1+ non-Tuner monsters\r\nIf this car...
# 2220      skill  Once per turn, choose 3 "Cyberdark" monsters f...
# 2729      skill  [If you lose 2000 or more LP, you can activate...
# 3054      skill  At the start of your Draw Phase, instead of dr...
# 5192      skill  The first time each DARK Machine monster you c...
# 6122      skill  Once per turn: You can send 1 "Ojama" card fro...
# 7097      skill  All "Ancient Gear" monsters gain 300 ATK. Each...
# 7113      skill  [Flip this card over when you activate this Sk...
# 7115      skill  [Flip this card over when you activate this Sk...
# 7141      skill  [At the start of the 3rd turn, if your LP is 3...
# 8483      skill  Activate this Skill during your Main Phase. Di...
# 8945       trap  You can target 1 Ritual Monster you control; S...
# 8946      spell  This card can be used to Ritual Summon any "No...
# 8947      spell  This card can be used to Ritual Summon any "No...
# 10118     skill  Activate the following Skill(s).\r\n● If a Rit...
# 11960     spell  Reveal 2 "Nouvelles" monsters with different n...
# 12574     skill  Activate this Skill during your Main Phase. On...
#
#                 race archetype  \
# 1179     Axel Brodie       NaN
# 1512            Bonz       NaN
# 1828          Weevil       NaN
# 2000          Dragon       NaN
# 2220   Zane Truesdal       NaN
# 2729            Yugi       NaN
# 3054             Rex       NaN
# 5192           Keith       NaN
# 6122   Chazz Princet       NaN
# 7097   Dr. Vellian C       NaN
# 7113         Pegasus       NaN
# 7115          Ishizu       NaN
# 7141         Pegasus       NaN
# 8483   Syrus Truesda       NaN
# 8945      Continuous    Recipe
# 8946          Ritual    Recipe
# 8947          Ritual    Recipe
# 10118  Lumis and Umb       NaN
# 11960         Normal       NaN
# 12574           Bonz       NaN
#
#                                                card_sets  \
# 1179   [{'set_name': 'Speed Duel GX: Duel Academy Box...
# 1512   [{'set_name': 'Speed Duel: Arena of Lost Souls...
# 1828   [{'set_name': 'Speed Duel Tournament Pack 3', ...
# 2000                                                 NaN
# 2220   [{'set_name': 'Speed Duel GX: Duel Academy Box...
# 2729   [{'set_name': 'Speed Duel Starter Decks: Desti...
# 3054   [{'set_name': 'Speed Duel: Scars of Battle', '...
# 5192   [{'set_name': 'Speed Duel: Scars of Battle', '...
# 6122   [{'set_name': 'Speed Duel GX: Duel Academy Box...
# 7097   [{'set_name': 'Speed Duel GX: Duel Academy Box...
# 7113   [{'set_name': 'Speed Duel Starter Decks: Desti...
# 7115   [{'set_name': 'Speed Duel Starter Decks: Desti...
# 7141   [{'set_name': 'Speed Duel Starter Decks: Desti...
# 8483   [{'set_name': 'Speed Duel GX: Midterm Paradox'...
# 8945                                                 NaN
# 8946                                                 NaN
# 8947                                                 NaN
# 10118  [{'set_name': 'Speed Duel: Battle City Box', '...
# 11960                                                NaN
# 12574  [{'set_name': 'Speed Duel: Trials of the Kingd...
#
#                                              card_images  \
# 1179   [{'id': 300302024, 'image_url': 'https://image...
# 1512   [{'id': 300101003, 'image_url': 'https://image...
# 1828   [{'id': 300104004, 'image_url': 'https://image...
# 2000   [{'id': 63436931, 'image_url': 'https://images...
# 2220   [{'id': 300302028, 'image_url': 'https://image...
# 2729   [{'id': 300201002, 'image_url': 'https://image...
# 3054   [{'id': 300103005, 'image_url': 'https://image...
# 5192   [{'id': 300103001, 'image_url': 'https://image...
# 6122   [{'id': 300302033, 'image_url': 'https://image...
# 7097   [{'id': 300302036, 'image_url': 'https://image...
# 7113   [{'id': 300201009, 'image_url': 'https://image...
# 7115   [{'id': 300201006, 'image_url': 'https://image...
# 7141   [{'id': 300201008, 'image_url': 'https://image...
# 8483   [{'id': 300302051, 'image_url': 'https://image...
# 8945   [{'id': 40551410, 'image_url': 'https://images...
# 8946   [{'id': 87778106, 'image_url': 'https://images...
# 8947   [{'id': 14166715, 'image_url': 'https://images...
# 10118  [{'id': 300302053, 'image_url': 'https://image...
# 11960  [{'id': 41773061, 'image_url': 'https://images...
# 12574  [{'id': 300104001, 'image_url': 'https://image...
#
#                                              card_prices  atk  def  level  \
# 1179   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 1512   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 1828   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 2000   [{'cardmarket_price': '0.00', 'tcgplayer_price...  0.0  0.0   12.0
# 2220   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 2729   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 3054   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 5192   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 6122   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 7097   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 7113   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 7115   [{'cardmarket_price': '0.13', 'tcgplayer_price...  NaN  NaN    NaN
# 7141   [{'cardmarket_price': '0.28', 'tcgplayer_price...  NaN  NaN    NaN
# 8483   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 8945   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 8946   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 8947   [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 10118  [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 11960  [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
# 12574  [{'cardmarket_price': '0.00', 'tcgplayer_price...  NaN  NaN    NaN
#
#       attribute  scale  linkval linkmarkers banlist_info
# 1179        NaN    NaN      NaN         NaN          NaN
# 1512        NaN    NaN      NaN         NaN          NaN
# 1828        NaN    NaN      NaN         NaN          NaN
# 2000      LIGHT    NaN      NaN         NaN          NaN
# 2220        NaN    NaN      NaN         NaN          NaN
# 2729        NaN    NaN      NaN         NaN          NaN
# 3054        NaN    NaN      NaN         NaN          NaN
# 5192        NaN    NaN      NaN         NaN          NaN
# 6122        NaN    NaN      NaN         NaN          NaN
# 7097        NaN    NaN      NaN         NaN          NaN
# 7113        NaN    NaN      NaN         NaN          NaN
# 7115        NaN    NaN      NaN         NaN          NaN
# 7141        NaN    NaN      NaN         NaN          NaN
# 8483        NaN    NaN      NaN         NaN          NaN
# 8945        NaN    NaN      NaN         NaN          NaN
# 8946        NaN    NaN      NaN         NaN          NaN
# 8947        NaN    NaN      NaN         NaN          NaN
# 10118       NaN    NaN      NaN         NaN          NaN
# 11960       NaN    NaN      NaN         NaN          NaN
# 12574       NaN    NaN      NaN         NaN          NaN

# %%
# Show all cards with "(Skill Card)" in their names
cards[cards["name"].str.contains("\(Skill Card\)")]

# Remove "(Skill Card)" from card names
cards["name"] = cards["name"].str.replace("\(Skill Card\)", "")
